# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %%
filepath = "../WeatherPy/Output/citiesweatherdata.csv"

city_data = pd.read_csv(filepath)
city_data.head()
# Out:
#             City    Lat    Long  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        iqaluit  63.75  -68.51     55.40        43          20       20.80
# 1         gallup  35.53 -108.74     82.99        21           1        5.82
# 2  alice springs -23.70  133.88     53.60        58           1        4.70
# 3       hermanus -34.42   19.23     60.01        75          92       14.00
# 4       klaksvik  62.23   -6.59     53.60        93          71       16.11
#
#   Country        Date
# 0      CA  1597255670
# 1      US  1597255670
# 2      AU  1597255487
# 3      ZA  1597255670
# 4      FO  1597255566

# %%
##prepare heatmap fields
locations = city_data[['Lat', 'Long']].astype(float)
humidity = city_data['Humidity'].astype(float)

locations
# Out:
#        Lat    Long
# 0    63.75  -68.51
# 1    35.53 -108.74
# 2   -23.70  133.88
# 3   -34.42   19.23
# 4    62.23   -6.59
# ..     ...     ...
# 544 -22.67  167.48
# 545 -35.17  173.17
# 546  38.49   43.38
# 547  51.16   54.99
# 548  -9.07  -44.36
#
# [549 rows x 2 columns]

# %%
#Create the heatmap
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=100, point_radius=1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
##Narrow down the data
ideal_cities = city_data.loc[(city_data['Max Temp'] < 90) & 
                             (city_data['Max Temp'] > 70) & 
                             (city_data["Wind Speed"] < 10) & 
                             (city_data['Cloudiness']<10)]

len(ideal_cities)
ideal_cities
# Out:
#                    City    Lat    Long  Max Temp  Humidity  Cloudiness  \
# 1                gallup  35.53 -108.74     82.99        21           1
# 35                 jalu  29.03   21.55     87.22        21           0
# 42            jamestown  42.10  -79.24     79.00        49           1
# 45        pacific grove  36.62 -121.92     73.00        60           1
# 62                  gat  31.61   34.76     82.99        85           1
# 114               ozark  37.02  -93.21     82.99        72           1
# 119            waingapu  -9.66  120.26     74.89        82           0
# 136          leamington  42.05  -82.61     82.40        39           1
# 144              laguna  38.42 -121.42     78.01        53           1
# 164        ponta do sol  32.67  -17.10     73.00        66           3
# 190           zhanaozen  43.30   52.80     76.14        27           0
# 193         makhachkala  42.98   47.50     73.00        73           8
# 211             cayenne   4.93  -52.33     84.20        70           0
# 221           kununurra -15.77  128.73     71.60        90           2
# 255          marsaxlokk  35.84   14.54     82.99        65           0
# 283          balkanabat  39.51   54.37     84.49        49           0
# 288            la palma  33.85 -118.05     86.00        39           1
# 308           shelburne  44.08  -80.20     84.99        37           1
# 320           piacabucu -10.41  -36.43     78.03        71           1
# 330              urbana  40.11  -88.21     82.99        61           1
# 331               ukiah  39.15 -123.21     79.00        60           1
# 373              artyom  40.47   50.33     75.20        60           0
# 402            griffith  41.53  -87.42     82.99        51           1
# 416            ishigaki  24.34  124.16     84.20        77           3
# 420  concepcion del oro  24.63 -101.42     72.91        39           0
# 451                roma  43.21  -75.46     81.00        54           1
# 453         parry sound  45.35  -80.03     75.99        67           0
# 465           mahajanga -15.72   46.32     71.58        64           0
# 466        sao domingos -13.40  -46.32     89.53        22           0
# 467               kahta  37.79   38.62     84.20        25           0
# 473             zurrieq  35.83   14.47     82.99        65           0
# 476              murgab  37.50   61.97     84.20        35           0
# 512          pozoblanco  38.38   -4.85     86.00        40           4
# 520            hamilton  39.18  -84.53     86.00        66           1
# 526            yinchuan  38.47  106.27     73.54        48           0
#
#      Wind Speed Country        Date
# 1          5.82      US  1597255670
# 35         5.28      LY  1597256120
# 42         5.82      US  1597255904
# 45         5.82      US  1597256123
# 62         3.00      IL  1597255922
# 114        2.39      US  1597256076
# 119        4.61      ID  1597256142
# 136        4.70      CA  1597256145
# 144        5.82      US  1597256147
# 164        2.21      PT  1597256152
# 190        4.43      KZ  1597256157
# 193        6.71      RU  1597256071
# 211        9.17      GF  1597256161
# 221        3.04      AU  1597256164
# 255        6.93      MT  1597256171
# 283        7.11      TM  1597256176
# 288        5.28      US  1597256080
# 308        4.70      CA  1597256104
# 320        9.64      BR  1597256184
# 330        6.93      US  1597256086
# 331        3.53      US  1597256186
# 373        9.17      AZ  1597256194
# 402        6.93      US  1597256200
# 416        6.33      JP  1597256203
# 420        6.69      MX  1597256203
# 451        6.93      US  1597255938
# 453        3.00      CA  1597256209
# 465        2.53      MG  1597256211
# 466        6.76      BR  1597256140
# 467        6.93      TR  1597256212
# 473        6.93      MT  1597256213
# 476        6.93      TM  1597256214
# 512        9.17      ES  1597256220
# 520        3.36      US  1597256222
# 526        8.39      CN  1597256223

# %%
##Get nearby hotels
lats = ideal_cities['Lat'].tolist()
longs = ideal_cities['Long'].tolist()
locations = zip(lats,longs)
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
hotel_name = []
# location = "39.51, 54.37"
# params = {
#     'location': location,
#     'radius': 5000,
#     'type': 'lodging',
#     'keyword': 'hotel',
#     'key': g_key
# }
    
# response=requests.get(base_url, params=params).json()

for location in locations:
    print()
    params = {
        'location': str(location[0]) + ',' + str(location[1]),
        'radius': 5000,
        'type': 'lodging',
        'keyword': 'hotel',
        'key': g_key
    }
    response = requests.get(base_url, params = params).json()
    try:
        hotel_name.append(response['results'][0]['name'])
    except:
        hotel_name.append('')
   
    

ideal_cities["Hotel"] = hotel_name
ideal_cities
# Out:
# /Users/tylerpitzer/opt/anaconda3/envs/pythondata2/lib/python3.6/site-packages/ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                    City    Lat    Long  Max Temp  Humidity  Cloudiness  \
# 1                gallup  35.53 -108.74     82.99        21           1
# 35                 jalu  29.03   21.55     87.22        21           0
# 42            jamestown  42.10  -79.24     79.00        49           1
# 45        pacific grove  36.62 -121.92     73.00        60           1
# 62                  gat  31.61   34.76     82.99        85           1
# 114               ozark  37.02  -93.21     82.99        72           1
# 119            waingapu  -9.66  120.26     74.89        82           0
# 136          leamington  42.05  -82.61     82.40        39           1
# 144              laguna  38.42 -121.42     78.01        53           1
# 164        ponta do sol  32.67  -17.10     73.00        66           3
# 190           zhanaozen  43.30   52.80     76.14        27           0
# 193         makhachkala  42.98   47.50     73.00        73           8
# 211             cayenne   4.93  -52.33     84.20        70           0
# 221           kununurra -15.77  128.73     71.60        90           2
# 255          marsaxlokk  35.84   14.54     82.99        65           0
# 283          balkanabat  39.51   54.37     84.49        49           0
# 288            la palma  33.85 -118.05     86.00        39           1
# 308           shelburne  44.08  -80.20     84.99        37           1
# 320           piacabucu -10.41  -36.43     78.03        71           1
# 330              urbana  40.11  -88.21     82.99        61           1
# 331               ukiah  39.15 -123.21     79.00        60           1
# 373              artyom  40.47   50.33     75.20        60           0
# 402            griffith  41.53  -87.42     82.99        51           1
# 416            ishigaki  24.34  124.16     84.20        77           3
# 420  concepcion del oro  24.63 -101.42     72.91        39           0
# 451                roma  43.21  -75.46     81.00        54           1
# 453         parry sound  45.35  -80.03     75.99        67           0
# 465           mahajanga -15.72   46.32     71.58        64           0
# 466        sao domingos -13.40  -46.32     89.53        22           0
# 467               kahta  37.79   38.62     84.20        25           0
# 473             zurrieq  35.83   14.47     82.99        65           0
# 476              murgab  37.50   61.97     84.20        35           0
# 512          pozoblanco  38.38   -4.85     86.00        40           4
# 520            hamilton  39.18  -84.53     86.00        66           1
# 526            yinchuan  38.47  106.27     73.54        48           0
#
#      Wind Speed Country        Date  \
# 1          5.82      US  1597255670
# 35         5.28      LY  1597256120
# 42         5.82      US  1597255904
# 45         5.82      US  1597256123
# 62         3.00      IL  1597255922
# 114        2.39      US  1597256076
# 119        4.61      ID  1597256142
# 136        4.70      CA  1597256145
# 144        5.82      US  1597256147
# 164        2.21      PT  1597256152
# 190        4.43      KZ  1597256157
# 193        6.71      RU  1597256071
# 211        9.17      GF  1597256161
# 221        3.04      AU  1597256164
# 255        6.93      MT  1597256171
# 283        7.11      TM  1597256176
# 288        5.28      US  1597256080
# 308        4.70      CA  1597256104
# 320        9.64      BR  1597256184
# 330        6.93      US  1597256086
# 331        3.53      US  1597256186
# 373        9.17      AZ  1597256194
# 402        6.93      US  1597256200
# 416        6.33      JP  1597256203
# 420        6.69      MX  1597256203
# 451        6.93      US  1597255938
# 453        3.00      CA  1597256209
# 465        2.53      MG  1597256211
# 466        6.76      BR  1597256140
# 467        6.93      TR  1597256212
# 473        6.93      MT  1597256213
# 476        6.93      TM  1597256214
# 512        9.17      ES  1597256220
# 520        3.36      US  1597256222
# 526        8.39      CN  1597256223
#
#                                                  Hotel
# 1                 SpringHill Suites by Marriott Gallup
# 35                                          Jalu Hotel
# 42                             Chautauqua Harbor Hotel
# 45   Hyatt Regency Monterey Hotel And Spa On Del Mo...
# 62                                          Desert Gat
# 114                                        Quality Inn
# 119                               Padadita Beach Hotel
# 136                                Seacliffe Inn (The)
# 144             Hilton Garden Inn Sacramento Elk Grove
# 164                                    Palace of Zinos
# 190                                       Hotel BasTau
# 193                     Central City Hotel Makhachkala
# 211                                     Royal Amazonia
# 221  Kimberleyland Waterfront Holiday Park | Kununu...
# 255                     Cugó Gran Macina Grand Harbour
# 283                                     Nebitchi Hotel
# 288                            Sheraton Cerritos Hotel
# 308                                    Shelburne Motel
# 320                                     Pousada Raizes
# 330                Hilton Garden Inn Champaign/ Urbana
# 331                                  Hampton Inn Ukiah
# 373                                    F marine resort
# 402               Holiday Inn Express & Suites Hammond
# 416                 Fusaki Beach Resort Hotel & Villas
# 420                                   Hotel Las Flores
# 451                            Wingate By Wyndham Rome
# 453                                        Comfort Inn
# 465                          Lodge des Terres Blanches
# 466  Hotel e Restaurante Uirapuru (Márcio uirapuru ...
# 467                                    Kommagene Hotel
# 473                                Lulu Boutique Hotel
# 476
# 512                                       Hotel Nomada
# 520
# 526                           Kempinski Hotel Yinchuan

# %%
ideal_cities["Hotel"].replace('', np.nan, inplace=True)
ideal_cities.dropna(inplace=True)
len(ideal_cities)
# Out:
# /Users/tylerpitzer/opt/anaconda3/envs/pythondata2/lib/python3.6/site-packages/pandas/core/generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# /Users/tylerpitzer/opt/anaconda3/envs/pythondata2/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 33

# %%
hotel_data = response.json()
hotel_data
# Out:
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}
