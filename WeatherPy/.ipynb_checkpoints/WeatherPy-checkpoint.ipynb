# %%
#Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
from scipy.stats import linregress

# %%
##Import API key
from api_keys import weather_api_key

#Citipy will determine city based on latitude and longitude
from citipy import citipy

#Get cities from output file
output_data_file = "../output_data/cities.csv"

##Set Latitude and Longitude ranges
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
##Set up URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

##Build query url
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
##List for holding latitudes/longitudes and cities
lat_lngs = []
cities = []


##get random lat and lng data
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

##Find the cities for each lat/lng
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    if city not in cities:
        cities.append(city)

# %%
##Create the dataframe
cities_df = pd.DataFrame({"City": cities})
cities_df["Lat"]=''
cities_df["Long"]=''
cities_df["Max Temp"]=''
cities_df["Humidity"]=''
cities_df["Cloudiness"]=''
cities_df["Wind Speed"]=''
cities_df["Country"]=''
cities_df["Date"]=''
cities_df.head()
# Out:
#             City Lat Long Max Temp Humidity Cloudiness Wind Speed Country Date
# 0        iqaluit
# 1         gallup
# 2  alice springs
# 3       hermanus
# 4       klaksvik

# %%
##just a sample to see what the is returned from the request
response = requests.get(query_url + 'frutal').json()
response
# Out:
# {'coord': {'lon': -48.94, 'lat': -20.02},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02d'}],
#  'base': 'stations',
#  'main': {'temp': 90.32,
#   'feels_like': 85.23,
#   'temp_min': 90.32,
#   'temp_max': 90.32,
#   'pressure': 1011,
#   'humidity': 21,
#   'sea_level': 1011,
#   'grnd_level': 957},
#  'visibility': 10000,
#  'wind': {'speed': 6.98, 'deg': 15},
#  'clouds': {'all': 15},
#  'dt': 1597252568,
#  'sys': {'country': 'BR', 'sunrise': 1597225153, 'sunset': 1597266144},
#  'timezone': -10800,
#  'id': 3462916,
#  'name': 'Frutal',
#  'cod': 200}

# %%
##Stuff I tried in for loop
# temperature = []
# humidity = []
# cloudiness = []
# wind_speed = []
#         humidity.append(response['main']['humidity'])
#         cloudiness.append(response['clouds']['all'])
#         wind_speed.append(response['wind']['speed'])

# %%
##Loop through the cities to poplulate the dataframe

print("Beginning Data Retrieval")
print("------------------------------")
for index, row in cities_df.iterrows():
    city = row['City']
    response = requests.get(query_url + city).json()
    
    try:
        cities_df.loc[index, 'Lat'] = response['coord']['lat']
        cities_df.loc[index, 'Long'] = response['coord']['lon']
        cities_df.loc[index, 'Max Temp'] = response['main']['temp_max']
        cities_df.loc[index, 'Humidity'] = response['main']['humidity']
        cities_df.loc[index, 'Cloudiness'] = response['clouds']['all']
        cities_df.loc[index, 'Wind Speed'] = response['wind']['speed']
        cities_df.loc[index, 'Country'] = response['sys']['country']
        cities_df.loc[index, 'Date'] = response['dt']

        print(f"Processing Record {index} of Set 1 | {city}")
        
    except:
        i = cities_df[cities_df['City']==city].index
        print(f"City {city} not found. Skipping...")
        cities_df.drop(i, inplace=True)  ###Remove the row from the dataframe
        pass
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 0 of Set 1 | iqaluit
# Processing Record 1 of Set 1 | gallup
# Processing Record 2 of Set 1 | alice springs
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | klaksvik
# Processing Record 5 of Set 1 | esperance
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | glendive
# Processing Record 8 of Set 1 | zhigalovo
# Processing Record 9 of Set 1 | olafsvik
# City vaitupu not found. Skipping...
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | carnarvon
# Processing Record 13 of Set 1 | zyryanka
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | te anau
# Processing Record 16 of Set 1 | sitka
# Processing Record 17 of Set 1 | dikson
# Processing Record 18 of Set 1 | nikolskoye
# Processing Record 19 of Set 1 | yulara
# Processing Record 20 of Set 1 | straumen
# City hihifo not found. Skipping...
# Processing Record 22 of Set 1 | tautira
# Processing Record 23 of Set 1 | boa vista
# Processing Record 24 of Set 1 | tarakan
# City taolanaro not found. Skipping...
# Processing Record 26 of Set 1 | lida
# Processing Record 27 of Set 1 | upernavik
# Processing Record 28 of Set 1 
# Processing Record 351 of Set 1 | wuxue
# Processing Record 352 of Set 1 | piacabucu
# Processing Record 353 of Set 1 | am timan
# City mrirt not found. Skipping...
# Processing Record 355 of Set 1 | peniche
# Processing Record 356 of Set 1 | fatsa
# Processing Record 357 of Set 1 | itarema
# Processing Record 358 of Set 1 | bandarbeyla
# Processing Record 359 of Set 1 | derzhavinsk
# Processing Record 360 of Set 1 | komsomolskiy
# Processing Record 361 of Set 1 | gioia tauro
# Processing Record 362 of Set 1 | aklavik
# Processing Record 363 of Set 1 | urbana
# City chagda not found. Skipping...
# Processing Record 365 of Set 1 | ukiah
# Processing Record 366 of Set 1 | guhagar
# Processing Record 367 of Set 1 | carlton
# Processing Record 368 of Set 1 | oum hadjer
# Processing Record 369 of Set 1 | itoman
# Processing Record 370 of Set 1 | rawson
# Processing Record 371 of Set 1 | pemangkat
# Processing Record 372 of Set 1 | parabel
# Processing Record 373 of Set 1 | port augusta
# Processing Record 374 of Set 1 | ziro
# Processing Record 375 of Set 1 | antofagasta
# Processing Record 376 of Set 1 | kedrovyy
# Processing Record 377 of Set 1 | manggar
# Processing Record 378 of Set 1 | iranshahr
# Processing Record 379 of Set 1 | mareeba
# Processing Record 380 of Set 1 | tupik
# Processing Record 381 of Set 1 | venado tuerto
# Processing Record 382 of Set 1 | kaele
# Processing Record 383 of Set 1 | cabo san lucas
# Processing Record 384 of Set 1 | wasilla
# Processing Record 385 of Set 1 | mahanoro
# Processing Record 386 of Set 1 | port shepstone
# Processing Record 387 of Set 1 | moron
# Processing Record 388 of Set 1 | guacheta
# Processing Record 389 of Set 1 | inuvik
# Processing Record 390 of Set 1 | rantauprapat
# City palabuhanratu not found. Skipping...
# Processing Record 392 of Set 1 | nevel
# Processing Record 393 of Set 1 | sept-iles
# Processing Record 394 of Set 1 | toguchin
# City attawapiskat not found. Skipping...
# Processing Record 396 of Set 1 | mayakonda
# Processing Record 397 of Set 1 | lompoc
# City bur gabo not found. Skipping...
# Processing Record 399 of Set 1 | san quintin
# Processing Record 400 of Set 1 | henties bay
# Processing Record 401 of Set 1 | abha
# City samalaeulu not found. Skipping...
# Processing Record 403 of Set 1 | lavrentiya
# Processing Record 404 of Set 1 | wanning
# Processing Record 405 of Set 1 | mount isa
# Processing Record 406 of Set 1 | san giorgio del sannio
# Processing Record 407 of Set 1 | sao filipe
# Processing Record 408 of Set 1 | labrea
# Processing Record 409 of Set 1 | lugo
# Processing Record 410 of Set 1 | daru
# Processing Record 411 of Set 1 | artyom
# Processing Record 412 of Set 1 | shiringushi
# Processing Record 413 of Set 1 | sibu
# Processing Record 414 of Set 1 | kaspiyskiy
# Processing Record 415 of Set 1 | acapulco
# Processing Record 416 of Set 1 | peleduy
# Processing Record 417 of Set 1 | nipawin
# Processing Record 418 of Set 1 | palmer
# Processing Record 419 of Set 1 | ostrovnoy
# Processing Record 420 of Set 1 | pevek
# Processing Record 421 of Set 1 | puerto baquerizo moreno
# Processing Record 422 of Set 1 | duku
# Processing Record 423 of Set 1 | makarov
# Processing Record 424 of Set 1 | richards bay
# Processing Record 425 of Set 1 | norrtalje
# Processing Record 426 of Set 1 | iwanai
# Processing Record 427 of Set 1 | pisco
# Processing Record 505 of Set 1 | vostochnyy
# Processing Record 506 of Set 1 | joshimath
# Processing Record 507 of Set 1 | talara
# Processing Record 508 of Set 1 | mahajanga
# Processing Record 509 of Set 1 | sao domingos
# Processing Record 510 of Set 1 | kahta
# Processing Record 511 of Set 1 | abhar
# Processing Record 512 of Set 1 | sao jose da coroa grande
# Processing Record 513 of Set 1 | pangnirtung
# Processing Record 514 of Set 1 | tomatlan
# Processing Record 515 of Set 1 | coos bay
# Processing Record 516 of Set 1 | zurrieq
# Processing Record 517 of Set 1 | penzance
# Processing Record 518 of Set 1 | santa maria
# City louisbourg not found. Skipping...
# Processing Record 520 of Set 1 | murgab
# Processing Record 521 of Set 1 | saint anthony
# Processing Record 522 of Set 1 | narasannapeta
# Processing Record 523 of Set 1 | hami
# Processing Record 524 of Set 1 | aksarka
# Processing Record 525 of Set 1 | sidney
# Processing Record 526 of Set 1 | puri
# Processing Record 527 of Set 1 | fortuna
# Processing Record 528 of Set 1 | benghazi
# Processing Record 529 of Set 1 | ilhabela
# City mahaicony not found. Skipping...
# Processing Record 531 of Set 1 | paramirim
# Processing Record 532 of Set 1 | balagansk
# City jiddah not found. Skipping...
# Processing Record 534 of Set 1 | beaune
# Processing Record 535 of Set 1 | mizdah
# Processing Record 536 of Set 1 | ozernovskiy
# Processing Record 537 of Set 1 | krasnyy chikoy
# Processing Record 538 of Set 1 | bubaque
# Processing Record 539 of Set 1 | melfort
# Processing Record 540 of Set 1 | bar harbor
# Processing Record 541 of Set 1 | cape canaveral
# Processing Record 542 of Set 1 | port lincoln
# Processing Record 543 of Set 1 | dire
# Processing Record 544 of Set 1 | la rioja
# Processing Record 545 of Set 1 | port-gentil
# Processing Record 546 of Set 1 | paicandu
# Processing Record 547 of Set 1 | sao bartolomeu de messines
# Processing Record 548 of Set 1 | lata
# Processing Record 549 of Set 1 | camocim
# Processing Record 550 of Set 1 | altay
# Processing Record 551 of Set 1 | maniitsoq
# Processing Record 552 of Set 1 | manzanillo
# Processing Record 553 of Set 1 | waipawa
# Processing Record 554 of Set 1 | idrinskoye
# Processing Record 555 of Set 1 | urengoy
# Processing Record 556 of Set 1 | beisfjord
# Processing Record 557 of Set 1 | teya
# Processing Record 558 of Set 1 | pozoblanco
# City tarudant not found. Skipping...
# Processing Record 560 of Set 1 | innisfail
# Processing Record 561 of Set 1 | kidal
# Processing Record 562 of Set 1 | grand baie
# Processing Record 563 of Set 1 | makakilo city
# Processing Record 564 of Set 1 | camacha
# Processing Record 565 of Set 1 | nelson bay
# Processing Record 566 of Set 1 | ulkan
# Processing Record 567 of Set 1 | hamilton
# Processing Record 568 of Set 1 | oxapampa
# Processing Record 569 of Set 1 | nemuro
# Processing Record 570 of Set 1 | velizh
# Processing Record 571 of Set 1 | marystown
# Processing Record 572 of Set 1 | sao felix do xingu
# Processing Record 573 of Set 1 | yinchuan
# Processing Record 574 of Set 1 | alyangula
# City dzhusaly not found. Skipping...
# Processing Record 576 of Set 1 | nizhniy kuranakh
# Processing Record 577 of Set 1 | qiongshan
# Processing Record 578 of Set 1 | araouane
# Processing Record 579 of Set 1 | ciudad bolivar
# City ngukurr not found. Skipping...
# Processing Record 581 of Set 1 | bridlington
# City marcona not found. Skipping...
# Processing Record 583 of Set 1 | soe
# Processing Record 584 of Set 1 | margate
# Processing Record 585 of Set 1 | alta floresta
# Processing Record 586 of Set 1 | bontang
# Processing Record 587 of Set 1 | buin
# Processing Record 588 of Set 1 | thinadhoo
# Processing Record 589 of Set 1 | gao
# Processing Record 590 of Set 1 | kharp
# Processing Record 591 of Set 1 | pimentel
# Processing Record 592 of Set 1 | oriximina
# Processing Record 593 of Set 1 | chimbote
# Processing Record 594 of Set 1 | vao
# Processing Record 595 of Set 1 | ahipara
# Processing Record 596 of Set 1 | van
# Processing Record 597 of Set 1 | sol-iletsk
# Processing Record 598 of Set 1 | bom jesus

# %%
##Export weather data to a csv
cities_df.to_csv("output/citiesweatherdata.csv", index = False)
cities_df.head()
# Out:
#             City    Lat    Long Max Temp Humidity Cloudiness Wind Speed  \
# 0        iqaluit  63.75  -68.51     55.4       43         20       20.8
# 1         gallup  35.53 -108.74    82.99       21          1       5.82
# 2  alice springs  -23.7  133.88     53.6       58          1        4.7
# 3       hermanus -34.42   19.23    60.01       75         92         14
# 4       klaksvik  62.23   -6.59     53.6       93         71      16.11
#
#   Country        Date
# 0      CA  1597255670
# 1      US  1597255670
# 2      AU  1597255487
# 3      ZA  1597255670
# 4      FO  1597255566

# %%
##Check for cities with humidity over 100%
cities_df.loc[cities_df['Humidity']>100]
# Out:
# Empty DataFrame
# Columns: [City, Lat, Long, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
##Temperature Scatterplot
plt.scatter(cities_df['Lat'], cities_df['Max Temp'], color = 'red', alpha = .5)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs. Max Temperature(8/12/2020)")

plt.savefig("Output/maxtemp.png")
plt.show()

# %%
##Humidity Scatterplot
plt.scatter(cities_df['Lat'], cities_df['Humidity'], alpha=.5)
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.title(f"City Latitude vs. Humidity(8/12/2020)")

plt.savefig("Output/humidity.png")
plt.show()

# %%
##Cloudiness Scatterplot
plt.scatter(cities_df['Lat'], cities_df['Cloudiness'], color = 'green', alpha = .5)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.title(f"City Latitude vs. Cloudiness(8/12/2020)")

plt.savefig("Output/cloudiness.png")
plt.show()

# %%
##Wind Speed Scatterplot
plt.scatter(cities_df['Lat'], cities_df['Wind Speed'],color='purple',alpha=.5)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs. Wind Speed(8/12/2020)")

plt.savefig("Output/wind_speed.png")
plt.show()

# %%
##Set up DataFrame for Northern and Southern hemispheres
cities_df['Lat'] = cities_df['Lat'].astype(float)
cities_df["Max Temp"] = cities_df["Max Temp"].astype(float)
cities_df["Humidity"] = cities_df["Humidity"].astype(float)
cities_df["Cloudiness"] = cities_df["Cloudiness"].astype(float)
cities_df["Wind Speed"] = cities_df["Wind Speed"].astype(float)

southern = cities_df.loc[cities_df["Lat"] < 0]
northern = cities_df.loc[cities_df["Lat"] > 0]

northern.to_csv("output/northern_hemisphere.csv", index = False)
southern.to_csv("output/southern_hemisphere.csv", index = False)

northern.head()
# Out:
#         City    Lat    Long  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    iqaluit  63.75  -68.51     55.40      43.0        20.0       20.80
# 1     gallup  35.53 -108.74     82.99      21.0         1.0        5.82
# 4   klaksvik  62.23   -6.59     53.60      93.0        71.0       16.11
# 7   glendive  47.11 -104.71     89.01      35.0         1.0       18.34
# 8  zhigalovo  54.81  105.16     57.96      84.0        10.0        1.12
#
#   Country        Date
# 0      CA  1597255670
# 1      US  1597255670
# 4      FO  1597255566
# 7      US  1597255805
# 8      RU  1597255806

# %%
##Northern Hemisphere Linear Regression for temperature
x_values = northern["Lat"]
y_values = northern["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

##Plot northern hemisphere
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values, "r-")

plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title("Northern Hemisphere Temps vs. Latitude")
plt.annotate(line_eq, (10,45), color = 'red', fontsize=14)

print(f"The r-squared is: {rvalue**2}")
plt.savefig("Output/north_maxtemp.png")
plt.show()
# Out:
# The r-squared is: 0.5202485675700675

# %%
##Southern Hemisphere Linear Regression for temperature
x_values = southern["Lat"]
y_values = southern["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

##Plot southern hemisphere
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values, "r-")

plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title("Southern Hemisphere Temps vs. Latitude")
plt.annotate(line_eq, (-50,80), color = 'red', fontsize=14)

print(f"The r-squared is: {rvalue**2}")
plt.savefig("Output/south_maxtemp.png")
plt.show()
# Out:
# The r-squared is: 0.660904691110598

# %%
##Northern Hemisphere Linear Regression for Humidity
x_values = northern["Lat"]
y_values = northern["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

##Plot northern hemisphere
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values, "r-")

plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.title("Northern Hemisphere Humidity vs. Latitude")
plt.annotate(line_eq, (10,20), color = 'red', fontsize=14)

print(f"The r-squared is: {rvalue**2}")
plt.savefig("Output/north_humidity.png")
plt.show()
# Out:
# The r-squared is: 0.001959223492298143

# %%
##Southern Hemisphere Linear Regression for humidity
x_values = southern["Lat"]
y_values = southern["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

##Plot southern hemisphere
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values, "r-")

plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.title("Southern Hemisphere Humidity vs. Latitude")
plt.annotate(line_eq, (-50,20), color = 'red', fontsize=14)

print(f"The r-squared is: {rvalue**2}")
plt.savefig("Output/south_humidity.png")
plt.show()
# Out:
# The r-squared is: 0.013909478799371763

# %%
##Northern Hemisphere Linear Regression for cloudiness
x_values = northern["Lat"]
y_values = northern["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

##Plot northern hemisphere
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values, "r-")

plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.title("Northern Hemisphere Cloudiness vs. Latitude")
plt.annotate(line_eq, (10,45), color = 'red', fontsize=14)

print(f"The r-squared is: {rvalue**2}")
plt.savefig("Output/north_cloudiness.png")
plt.show()
# Out:
# The r-squared is: 0.0015881334885982279

# %%
##Southern Hemisphere Linear Regression for cloudiness
x_values = southern["Lat"]
y_values = southern["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

##Plot southern hemisphere
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values, "r-")

plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.title("Southern Hemisphere Cloudiness vs. Latitude")
plt.annotate(line_eq, (-50,80), color = 'red', fontsize=14)

print(f"The r-squared is: {rvalue**2}")
plt.savefig("Output/south_cloudiness.png")
plt.show()
# Out:
# The r-squared is: 3.1710768037330993e-07

# %%
##Northern Hemisphere Linear Regression for Wind Speed
x_values = northern["Lat"]
y_values = northern["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

##Plot northern hemisphere
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values, "r-")

plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Northern Hemisphere Wind Speed vs. Latitude")
plt.annotate(line_eq, (10,25), color = 'red', fontsize=14)

print(f"The r-squared is: {rvalue**2}")
plt.savefig("Output/north_windspeed.png")
plt.show()
# Out:
# The r-squared is: 0.0015042132816024708

# %%
##Southern Hemisphere Linear Regression Wind Speed
x_values = southern["Lat"]
y_values = southern["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

##Plot southern hemisphere
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values, "r-")

plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Southern Hemisphere Wind Speed vs. Latitude")
plt.annotate(line_eq, (-50,20), color = 'red', fontsize=14)

print(f"The r-squared is: {rvalue**2}")
plt.savefig("Output/south_windspeed.png")
plt.show()
# Out:
# The r-squared is: 0.03211836395836535
